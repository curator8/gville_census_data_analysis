# %% [markdown]
# ## Different Economical Regions in NC
#
# # list of counties and codes
#
# ```(python)
# county_names = df_2019_to_2014['county_name'].unique().tolist()
# county_code = df_2019_to_2014['county_code'].unique().tolist()
#
# pd.DataFrame(zip(county_names, county_code), columns = ['county_names', 'county_code'])
# ```
# ### Inner banks
#
# greene,
# wilson,
# jones,
# craven,
# pamlico,
# beaufort,
# pitt,
# edge-combe,
# halifax,
# martin,
# bertie,
# washington,
# tyrrell,
# hertford,
# north-ampton,
# gates,
# chowan,
# perquimans,
# pasquotank,
# carnden,
#
#
#
# 22 counties
#
#
#
#
#
#
#
# ### Outer banks
#
# Dare, hyde, currituck, carteret
#
# 4 counties
#
#
#
#
#
#
#
# ### Southeast
#
# Columbus, Duplin, Onslow, Pender, brunswick, new hanover
#
# 6 counties
#
#
#
#
#
#
#
# ### Sandhills
#
# Cumberland, Harnett, Hoke, Moore, Richmond,Scotland, rebeson, bladen, sampson
#
# 9 counties
#
#
#
#
#
#
#
# ### Triangle
#
# Chatham,
# Durham,
# Franklin,
# Granville,
# Johnston,
# Lee,
# Person,
# Wake,
# Vance,
# orange
# warren,
# nash
#
# 12 counties
#
#
#
#
#
#
#
# ### Piedmont triad
#
# Guilford,
# Forsyth,
# Alamance,
# Davidson,
# Randolph,
# Rockingham,
# Surry,
# Stokes,
# Davie,
# Yadkin,
# caswell,
# montgomery
#
# 12 counties
#
#
#
#
#
#
#
# ### Metrolina (Charlotte metropolitan area)
#
# Mecklenburg,
# Cabarrus,
# Gaston,
# Iredell,
# Lincoln,
# Rowan,
# Anson,
# Union,
# Cleveland,
# Stanly,
# catawba,
# alexander
#
# 12 counties
#
#
#
#
#
#
#
# ### Mountains
#
# cherokee,
# graham,
# swain,
# haywood,
# jackson,
# macon,
# clay,
# transylvania,
# henderson,
# buncombe,
# madison,
# yancey,
# mcdowell,
# rutherford,
# polk,
# burke,
# avery,
# mitchell,
# watauga,
# caldwell,
# wilkes,
# ashe,
# alleghany
#
#
# 23 counties
